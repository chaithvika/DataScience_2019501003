# %%
import pandas as pd 
import numpy as np

# %%
name = pd.read_csv('C:/Users/klagadap/DataScience_2019501003-master/Data Analytics and Visualization/Task - 1/IMDB Data/name_basics.tsv', sep = "\t", header = 0)
basics = pd.read_csv('C:/Users/klagadap/DataScience_2019501003-master/Data Analytics and Visualization/Task - 1/IMDB Data/title_basics.tsv', sep = "\t", header = 0)
ratings = pd.read_csv('C:/Users/klagadap/DataScience_2019501003-master/Data Analytics and Visualization/Task - 1/IMDB Data/title_ratings.tsv', sep = "\t", header = 0)

# %%
temp_basics = basics[basics["startYear"] != "\\N"]
temp_basics = temp_basics.astype({"startYear":"int"})
print(temp_basics.dtypes)
print('++++++++++++++++++++')
print(ratings.dtypes)
# Out:
# tconst            object
# titleType         object
# primaryTitle      object
# originalTitle     object
# isAdult           object
# startYear          int32
# endYear           object
# runtimeMinutes    object
# genres            object
# dtype: object
# ++++++++++++++++++++
# tconst            object
# averageRating    float64
# numVotes           int64
# dtype: object

# %%
sol = pd.merge(temp_basics, ratings, on = "tconst")
print(sol.head())
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult  startYear endYear runtimeMinutes                    genres  \
# 0       0       1894      \N              1         Documentary,Short
# 1       0       1892      \N              5           Animation,Short
# 2       0       1892      \N              4  Animation,Comedy,Romance
# 3       0       1892      \N             12           Animation,Short
# 4       0       1893      \N              1              Comedy,Short
#
#    averageRating  numVotes
# 0            5.7      1705
# 1            6.1       210
# 2            6.5      1464
# 3            6.2       123
# 4            6.2      2265

# %% [markdown]
# # To Find the 20 most popular movies with a rank more than 8.0

# %%
temp_result = sol[(sol['averageRating'] > 8.0) & (sol["titleType"] == 'movie')]
result = temp_result.sort_values(by = 'numVotes', ascending = False)
result.head(20)
# Out:
#            tconst titleType  \
# 82010   tt0111161     movie
# 247885  tt0468569     movie
# 603333  tt1375666     movie
# 98403   tt0137523     movie
# 81793   tt0110912     movie
# 80919   tt0109830     movie
# 96277   tt0133093     movie
# 89790   tt0120737     movie
# 113371  tt0167260     movie
# 45835   tt0068646     movie
# 390917  tt0816692     movie
# 592796  tt1345836     movie
# 113372  tt0167261     movie
# 84561   tt0114369     movie
# 699807  tt1853728     movie
# 115812  tt0172495     movie
# 207781  tt0372784     movie
# 75207   tt0102926     movie
# 202680  tt0361748     movie
# 89852   tt0120815     movie
#
#                                              primaryTitle  \
# 82010                            The Shawshank Redemption
# 247885                                    The Dark Knight
# 603333                                          Inception
# 98403                                          Fight Club
# 81793                                        Pulp Fiction
# 80919                                        Forrest Gump
# 96277                                          The Matrix
# 89790   The Lord of the Rings: The Fellowship of the Ring
# 113371      The Lord of the Rings: The Return of the King
# 45835                                       The Godfather
# 390917                                       Interstellar
# 592796                              The Dark Knight Rises
# 113372              The Lord of the Rings: The Two Towers
# 84561                                               Se7en
# 699807                                   Django Unchained
# 115812                                          Gladiator
# 207781                                      Batman Begins
# 75207                            The Silence of the Lambs
# 202680                               Inglourious Basterds
# 89852                                 Saving Private Ryan
#
#                                             originalTitle isAdult  startYear  \
# 82010                            The Shawshank Redemption       0       1994
# 247885                                    The Dark Knight       0       2008
# 603333                                          Inception       0       2010
# 98403                                          Fight Club       0       1999
# 81793                                        Pulp Fiction       0       1994
# 80919                                        Forrest Gump       0       1994
# 96277                                          The Matrix       0       1999
# 89790   The Lord of the Rings: The Fellowship of the Ring       0       2001
# 113371      The Lord of the Rings: The Return of the King       0       2003
# 45835                                       The Godfather       0       1972
# 390917                                       Interstellar       0       2014
# 592796                              The Dark Knight Rises       0       2012
# 113372              The Lord of the Rings: The Two Towers       0       2002
# 84561                                               Se7en       0       1995
# 699807                                   Django Unchained       0       2012
# 115812                                          Gladiator       0       2000
# 207781                                      Batman Begins       0       2005
# 75207                            The Silence of the Lambs       0       1991
# 202680                               Inglourious Basterds       0       2009
# 89852                                 Saving Private Ryan       0       1998
#
#        endYear runtimeMinutes                   genres  averageRating  \
# 82010       \N            142                    Drama            9.3
# 247885      \N            152       Action,Crime,Drama            9.0
# 603333      \N            148  Action,Adventure,Sci-Fi            8.8
# 98403       \N            139                    Drama            8.8
# 81793       \N            154              Crime,Drama            8.9
# 80919       \N            142            Drama,Romance            8.8
# 96277       \N            136            Action,Sci-Fi            8.7
# 89790       \N            178   Action,Adventure,Drama            8.8
# 113371      \N            201   Action,Adventure,Drama            8.9
# 45835       \N            175              Crime,Drama            9.2
# 390917      \N            169   Adventure,Drama,Sci-Fi            8.6
# 592796      \N            164         Action,Adventure            8.4
# 113372      \N            179   Action,Adventure,Drama            8.7
# 84561       \N            127      Crime,Drama,Mystery            8.6
# 699807      \N            165            Drama,Western            8.4
# 115812      \N            155   Action,Adventure,Drama            8.5
# 207781      \N            140         Action,Adventure            8.2
# 75207       \N            118     Crime,Drama,Thriller            8.6
# 202680      \N            153      Adventure,Drama,War            8.3
# 89852       \N            169                Drama,War            8.6
#
#         numVotes
# 82010    2396761
# 247885   2358238
# 603333   2116116
# 98403    1893832
# 81793    1863975
# 80919    1853196
# 96277    1711986
# 89790    1694532
# 113371   1673765
# 45835    1660096
# 390917   1560783
# 592796   1546316
# 113372   1513569
# 84561    1478335
# 699807   1390229
# 115812   1367315
# 207781   1333314
# 75207    1299596
# 202680   1298830
# 89852    1263493

# %% [markdown]
# # To find the 20 best rated movies with over 40,000 votes in the 2000s (year >= 2000)

# %%
rated_movies = sol[(sol["numVotes"] >= 40000) & (sol["startYear"] >= 2000) & (sol["titleType"] == 'movie')]
res = rated_movies.sort_values(by = 'averageRating', ascending = False)
res.head(20)
# Out:
#              tconst titleType  \
# 787050    tt2592910     movie
# 450217   tt10189514     movie
# 247885    tt0468569     movie
# 113371    tt0167260     movie
# 89790     tt0120737     movie
# 603333    tt1375666     movie
# 113372    tt0167261     movie
# 979514    tt5813916     movie
# 185055    tt0317248     movie
# 1031165   tt6751668     movie
# 390917    tt0816692     movie
# 150103    tt0245429     movie
# 1108387   tt8503618     movie
# 786471    tt2582802     movie
# 223448    tt0407887     movie
# 668967    tt1675434     movie
# 153763    tt0253474     movie
# 619048    tt1424432     movie
# 115812    tt0172495     movie
# 253813    tt0482571     movie
#
#                                               primaryTitle  \
# 787050                              CM101MMXI Fundamentals
# 450217                                     Soorarai Pottru
# 247885                                     The Dark Knight
# 113371       The Lord of the Rings: The Return of the King
# 89790    The Lord of the Rings: The Fellowship of the Ring
# 603333                                           Inception
# 113372               The Lord of the Rings: The Two Towers
# 979514                                     The Mountain II
# 185055                                         City of God
# 1031165                                           Parasite
# 390917                                        Interstellar
# 150103                                       Spirited Away
# 1108387                                           Hamilton
# 786471                                            Whiplash
# 223448                                        The Departed
# 668967                                    The Intouchables
# 153763                                         The Pianist
# 619048                                               Senna
# 115812                                           Gladiator
# 253813                                        The Prestige
#
#                                              originalTitle isAdult  startYear  \
# 787050                              CM101MMXI Fundamentals       0       2013
# 450217                                     Soorarai Pottru       0       2020
# 247885                                     The Dark Knight       0       2008
# 113371       The Lord of the Rings: The Return of the King       0       2003
# 89790    The Lord of the Rings: The Fellowship of the Ring       0       2001
# 603333                                           Inception       0       2010
# 113372               The Lord of the Rings: The Two Towers       0       2002
# 979514                                              Dag II       0       2016
# 185055                                      Cidade de Deus       0       2002
# 1031165                                       Gisaengchung       0       2019
# 390917                                        Interstellar       0       2014
# 150103                       Sen to Chihiro no kamikakushi       0       2001
# 1108387                                           Hamilton       0       2020
# 786471                                            Whiplash       0       2014
# 223448                                        The Departed       0       2006
# 668967                                        Intouchables       0       2011
# 153763                                         The Pianist       0       2002
# 619048                                               Senna       0       2010
# 115812                                           Gladiator       0       2000
# 253813                                        The Prestige       0       2006
#
#         endYear runtimeMinutes                       genres  averageRating  \
# 787050       \N            139           Comedy,Documentary            9.2
# 450217       \N            153                        Drama            9.1
# 247885       \N            152           Action,Crime,Drama            9.0
# 113371       \N            201       Action,Adventure,Drama            8.9
# 89790        \N            178       Action,Adventure,Drama            8.8
# 603333       \N            148      Action,Adventure,Sci-Fi            8.8
# 113372       \N            179       Action,Adventure,Drama            8.7
# 979514       \N            135             Action,Drama,War            8.7
# 185055       \N            130                  Crime,Drama            8.6
# 1031165      \N            132        Comedy,Drama,Thriller            8.6
# 390917       \N            169       Adventure,Drama,Sci-Fi            8.6
# 150103       \N            125   Adventure,Animation,Family            8.6
# 1108387      \N            160      Biography,Drama,History            8.5
# 786471       \N            106                  Drama,Music            8.5
# 223448       \N            151         Crime,Drama,Thriller            8.5
# 668967       \N            112       Biography,Comedy,Drama            8.5
# 153763       \N            150        Biography,Drama,Music            8.5
# 619048       \N            106  Biography,Documentary,Sport            8.5
# 115812       \N            155       Action,Adventure,Drama            8.5
# 253813       \N            130         Drama,Mystery,Sci-Fi            8.5
#
#          numVotes
# 787050      44260
# 450217      79853
# 247885    2358238
# 113371    1673765
# 89790     1694532
# 603333    2116116
# 113372    1513569
# 979514     106044
# 185055     709698
# 1031165    610688
# 390917    1560783
# 150103     671477
# 1108387     64753
# 786471     739629
# 223448    1213898
# 668967     779033
# 153763     749459
# 619048      65310
# 115812    1367315
# 253813    1216713
